# %% [markdown]
# <a href="https://colab.research.google.com/github/Baeltor/PCD/blob/prog/NotebooksMLII/Generaci%C3%B3n_de_texto_con_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import layers

import numpy as np
import random
import io

# %%
path = keras.utils.get_file(
    "nietzsche.txt",
    origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt",
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype="bool")
y = np.zeros((len(sentences), len(chars)), dtype="bool")
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 ━━━━━━━━━━━━━━━━━━━━ 1s 2us/step
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285

# %%
sentences
# Out:
# ['preface   supposing that truth is a woma',
#  'face   supposing that truth is a woman--',
#  'e   supposing that truth is a woman--wha',
#  ' supposing that truth is a woman--what t',
#  'pposing that truth is a woman--what then',
#  'sing that truth is a woman--what then? i',
#  'g that truth is a woman--what then? is t',
#  'hat truth is a woman--what then? is ther',
#  ' truth is a woman--what then? is there n',
#  'uth is a woman--what then? is there not ',
#  ' is a woman--what then? is there not gro',
#  ' a woman--what then? is there not ground',
#  'woman--what then? is there not ground fo',
#  'an--what then? is there not ground for s',
#  '-what then? is there not ground for susp',
#  'at then? is there not ground for suspect',
#  'then? is there not ground for suspecting',
#  'n? is there not ground for suspecting th',
#  'is there not ground for suspecting that ',
#  'there not ground for suspecting that all',
#  're not ground for suspecting that all ph',
#  'not ground for suspecting that all philo',
#  ' ground for suspecting that all philosop',
#  'ound for suspecting that all philosopher',
#  'd for suspecting that all philosophers, ',
#  'or suspecting that all philosophers, in ',
#  'suspecting that all philosophers, in so ',
#  'pecting that all philosophers, in so far',
#  'ting that all philosophers, in so far as',
#  'g that all philosophers, in so far as th',
#  'hat all philosophers, in so far as they ',
#  ' all philosophers, in so far as they hav',
#  'l philosophers, in so far as they have b',
#  'hilosophers, in so far as they have been',
#  'osophers, in so far as they have been do',
#  'phers, in so far as they have been dogma',
#  'rs, in so far as they have been dogmatis',
#  ' in so far as they have been dogmatists,',
#  ' so far as they have been dogmatists, ha',
#  ' far as they have been dogmatists, have ',
#  'r as they have been dogmatists, have fai',
#  's they have been dogmatists, have failed',
#  'hey have been dogmatists, have failed to',
#  ' have been dogmatists, have failed to un',
#  've been dogmatists, have failed to under',
#  'been dogmatists, have failed to understa',
#  'n dogmatists, have failed to understand ',
#  'ogmatists, have failed to understand wom',
#  'atists, have failed to understand women-',
#  'sts, have failed to understand women--th',
#  ', have failed to understand women--that ',
#  'ave failed to understand women--that the',
#  ' failed to understand women--that the te',
#  'iled to understand women--that the terri',
#  'd to understand women--that the terrible',
#  'o understand women--that the terrible se',
#  'nderstand women--that the terrible serio',
#  'rstand women--that the terrible seriousn',
#  'and women--that the terrible seriousness',
#  ' women--that the terrible seriousness an',
#  'men--that the terrible seriousness and c',
#  '--that the terrible seriousness and clum',
#  'hat the terrible seriousness and clumsy ',
#  ' the terrible seriousness and clumsy imp',
#  'e terrible seriousness and clumsy import',
#  'errible seriousness and clumsy importuni',
#  'ible seriousness and clumsy importunity ',
#  'e seriousness and clumsy importunity wit',
#  'eriousness and clumsy importunity with w',
#  'ousness and clumsy importunity with whic',
#  'ness and clumsy importunity with which t',
#  's and clumsy importunity with which they',
#  'nd clumsy importunity with which they ha',
#  'clumsy importunity with which they have ',
#  'msy importunity with which they have usu',
#  ' importunity with which they have usuall',
#  'portunity with which they have usually p',
#  'tunity with which they have usually paid',
#  'ity with which they have usually paid th',
#  ' with which they have usually paid their',
#  'th which they have usually paid their ad',
#  'which they have usually paid their addre',
#  'ch they have usually paid their addresse',
#  'they have usually paid their addresses t',
#  'y have usually paid their addresses to t',
#  'ave usually paid their addresses to trut',
#  ' usually paid their addresses to truth, ',
#  'ually paid their addresses to truth, hav',
#  'ly paid their addresses to truth, have b',
#  'paid their addresses to truth, have been',
#  'd their addresses to truth, have been un',
#  'heir addresses to truth, have been unski',
#  'r addresses to truth, have been unskille',
#  'ddresses to truth, have been unskilled a',
#  'esses to truth, have been unskilled and ',
#  'es to truth, have been unskilled and uns',
#  'to truth, have been unskilled and unseem',
#  'truth, have been unskilled and unseemly ',
#  'th, have been unskilled and unseemly met',
#  ' have been unskilled and unseemly method',
#  've been unskilled and unseemly methods f',
#  'been unskilled and unseemly methods for ',
#  'n unskilled and unseemly methods for win',
#  'nskilled and unseemly methods for winnin',
#  'illed and unseemly methods for winning a',
#  'ed and unseemly methods for winning a wo',
#  'and unseemly methods for winning a woman',
#  ' unseemly methods for winning a woman? c',
#  'seemly methods for winning a woman? cert',
#  'mly methods for winning a woman? certain',
#  ' methods for winning a woman? certainly ',
#  'thods for winning a woman? certainly she',
#  'ds for winning a woman? certainly she ha',
#  'for winning a woman? certainly she has n',
#  ' winning a woman? certainly she has neve',
#  'nning a woman? certainly she has never a',
#  'ng a woman? certainly she has never allo',
#  'a woman? certainly she has never allowed',
#  'oman? certainly she has never allowed he',
#  'n? certainly she has never allowed herse',
#  'certainly she has never allowed herself ',
#  'tainly she has never allowed herself to ',
#  'nly she has never allowed herself to be ',
#  ' she has never allowed herself to be won',
#  'e has never allowed herself to be won; a',
#  'as never allowed herself to be won; and ',
#  'never allowed herself to be won; and at ',
#  'er allowed herself to be won; and at pre',
#  'allowed herself to be won; and at presen',
#  'owed herself to be won; and at present e',
#  'd herself to be won; and at present ever',
#  'erself to be won; and at present every k',
#  'elf to be won; and at present every kind',
#  ' to be won; and at present every kind of',
#  ' be won; and at present every kind of do',
#  ' won; and at present every kind of dogma',
#  'n; and at present every kind of dogma st',
#  'and at present every kind of dogma stand',
#  ' at present every kind of dogma stands w',
#  ' present every kind of dogma stands with',
#  'esent every kind of dogma stands with sa',
#  'nt every kind of dogma stands with sad a',
#  'every kind of dogma stands with sad and ',
#  'ry kind of dogma stands with sad and dis',
#  'kind of dogma stands with sad and discou',
#  'd of dogma stands with sad and discourag',
#  'f dogma stands with sad and discouraged ',
#  'ogma stands with sad and discouraged mie',
#  'a stands with sad and discouraged mien--',
#  'tands with sad and discouraged mien--if,',
#  'ds with sad and discouraged mien--if, in',
#  'with sad and discouraged mien--if, indee',
#  'h sad and discouraged mien--if, indeed, ',
#  'ad and discouraged mien--if, indeed, it ',
#  'and discouraged mien--if, indeed, it sta',
#  ' discouraged mien--if, indeed, it stands',
#  'scouraged mien--if, indeed, it stands at',
#  'uraged mien--if, indeed, it stands at al',
#  'ged mien--if, indeed, it stands at all! ',
#  ' mien--if, indeed, it stands at all! for',
#  'en--if, indeed, it stands at all! for th',
#  '-if, indeed, it stands at all! for there',
#  ', indeed, it stands at all! for there ar',
#  'ndeed, it stands at all! for there are s',
#  'ed, it stands at all! for there are scof',
#  ' it stands at all! for there are scoffer',
#  ' stands at all! for there are scoffers w',
#  'ands at all! for there are scoffers who ',
#  's at all! for there are scoffers who mai',
#  't all! for there are scoffers who mainta',
#  'll! for there are scoffers who maintain ',
#  ' for there are scoffers who maintain tha',
#  'r there are scoffers who maintain that i',
#  'here are scoffers who maintain that it h',
#  'e are scoffers who maintain that it has ',
#  're scoffers who maintain that it has fal',
#  'scoffers who maintain that it has fallen',
#  'ffers who maintain that it has fallen, t',
#  'rs who maintain that it has fallen, that',
#  'who maintain that it has fallen, that al',
#  ' maintain that it has fallen, that all d',
#  'intain that it has fallen, that all dogm',
#  'ain that it has fallen, that all dogma l',
#  ' that it has fallen, that all dogma lies',
#  'at it has fallen, that all dogma lies on',
#  'it has fallen, that all dogma lies on th',
#  'has fallen, that all dogma lies on the g',
#  ' fallen, that all dogma lies on the grou',
#  'llen, that all dogma lies on the ground-',
#  'n, that all dogma lies on the ground--na',
#  'that all dogma lies on the ground--nay m',
#  't all dogma lies on the ground--nay more',
#  'll dogma lies on the ground--nay more, t',
#  'dogma lies on the ground--nay more, that',
#  'ma lies on the ground--nay more, that it',
#  'lies on the ground--nay more, that it is',
#  's on the ground--nay more, that it is at',
#  'n the ground--nay more, that it is at it',
#  'he ground--nay more, that it is at its l',
#  'ground--nay more, that it is at its last',
#  'und--nay more, that it is at its last ga',
#  '--nay more, that it is at its last gasp.',
#  'ay more, that it is at its last gasp. bu',
#  'more, that it is at its last gasp. but t',
#  'e, that it is at its last gasp. but to s',
#  'that it is at its last gasp. but to spea',
#  't it is at its last gasp. but to speak s',
#  't is at its last gasp. but to speak seri',
#  's at its last gasp. but to speak serious',
#  't its last gasp. but to speak seriously,',
#  'ts last gasp. but to speak seriously, th',
#  'last gasp. but to speak seriously, there',
#  't gasp. but to speak seriously, there ar',
#  'asp. but to speak seriously, there are g',
#  '. but to speak seriously, there are good',
#  'ut to speak seriously, there are good gr',
#  'to speak seriously, there are good groun',
#  'speak seriously, there are good grounds ',
#  'ak seriously, there are good grounds for',
#  'seriously, there are good grounds for ho',
#  'iously, there are good grounds for hopin',
#  'sly, there are good grounds for hoping t',
#  ', there are good grounds for hoping that',
#  'here are good grounds for hoping that al',
#  'e are good grounds for hoping that all d',
#  're good grounds for hoping that all dogm',
#  'good grounds for hoping that all dogmati',
#  'd grounds for hoping that all dogmatizin',
#  'rounds for hoping that all dogmatizing i',
#  'nds for hoping that all dogmatizing in p',
#  ' for hoping that all dogmatizing in phil',
#  'r hoping that all dogmatizing in philoso',
#  'oping that all dogmatizing in philosophy',
#  'ng that all dogmatizing in philosophy, w',
#  'that all dogmatizing in philosophy, what',
#  't all dogmatizing in philosophy, whateve',
#  'll dogmatizing in philosophy, whatever s',
#  'dogmatizing in philosophy, whatever sole',
#  'matizing in philosophy, whatever solemn,',
#  'izing in philosophy, whatever solemn, wh',
#  'ng in philosophy, whatever solemn, whate',
#  'in philosophy, whatever solemn, whatever',
#  'philosophy, whatever solemn, whatever co',
#  'losophy, whatever solemn, whatever concl',
#  'ophy, whatever solemn, whatever conclusi',
#  'y, whatever solemn, whatever conclusive ',
#  'whatever solemn, whatever conclusive and',
#  'tever solemn, whatever conclusive and de',
#  'er solemn, whatever conclusive and decid',
#  'solemn, whatever conclusive and decided ',
#  'emn, whatever conclusive and decided air',
#  ', whatever conclusive and decided airs i',
#  'hatever conclusive and decided airs it h',
#  'ever conclusive and decided airs it has ',
#  'r conclusive and decided airs it has ass',
#  'onclusive and decided airs it has assume',
#  'lusive and decided airs it has assumed, ',
#  'ive and decided airs it has assumed, may',
#  ' and decided airs it has assumed, may ha',
#  'd decided airs it has assumed, may have ',
#  'ecided airs it has assumed, may have bee',
#  'ded airs it has assumed, may have been o',
#  ' airs it has assumed, may have been only',
#  'rs it has assumed, may have been only a ',
#  'it has assumed, may have been only a nob',
#  'has assumed, may have been only a noble ',
#  ' assumed, may have been only a noble pue',
#  'sumed, may have been only a noble pueril',
#  'ed, may have been only a noble puerilism',
#  ' may have been only a noble puerilism an',
#  'y have been only a noble puerilism and t',
#  'ave been only a noble puerilism and tyro',
#  ' been only a noble puerilism and tyronis',
#  'en only a noble puerilism and tyronism; ',
#  'only a noble puerilism and tyronism; and',
#  'y a noble puerilism and tyronism; and pr',
#  ' noble puerilism and tyronism; and proba',
#  'ble puerilism and tyronism; and probably',
#  ' puerilism and tyronism; and probably th',
#  'erilism and tyronism; and probably the t',
#  'lism and tyronism; and probably the time',
#  'm and tyronism; and probably the time is',
#  'nd tyronism; and probably the time is at',
#  'tyronism; and probably the time is at ha',
#  'onism; and probably the time is at hand ',
#  'sm; and probably the time is at hand whe',
#  ' and probably the time is at hand when i',
#  'd probably the time is at hand when it w',
#  'robably the time is at hand when it will',
#  'ably the time is at hand when it will be',
#  'y the time is at hand when it will be on',
#  'he time is at hand when it will be once ',
#  'time is at hand when it will be once and',
#  'e is at hand when it will be once and ag',
#  's at hand when it will be once and again',
#  't hand when it will be once and again un',
#  'and when it will be once and again under',
#  ' when it will be once and again understo',
#  'en it will be once and again understood ',
#  'it will be once and again understood wha',
#  'will be once and again understood what h',
#  'l be once and again understood what has ',
#  'e once and again understood what has act',
#  'nce and again understood what has actual',
#  ' and again understood what has actually ',
#  'd again understood what has actually suf',
#  'gain understood what has actually suffic',
#  'n understood what has actually sufficed ',
#  'nderstood what has actually sufficed for',
#  'rstood what has actually sufficed for th',
#  'ood what has actually sufficed for the b',
#  ' what has actually sufficed for the basi',
#  'at has actually sufficed for the basis o',
#  'has actually sufficed for the basis of s',
#  ' actually sufficed for the basis of such',
#  'tually sufficed for the basis of such im',
#  'lly sufficed for the basis of such impos',
#  ' sufficed for the basis of such imposing',
#  'fficed for the basis of such imposing an',
#  'ced for the basis of such imposing and a',
#  ' for the basis of such imposing and abso',
#  'r the basis of such imposing and absolut',
#  'he basis of such imposing and absolute p',
#  'basis of such imposing and absolute phil',
#  'is of such imposing and absolute philoso',
#  'of such imposing and absolute philosophi',
#  'such imposing and absolute philosophical',
#  'h imposing and absolute philosophical ed',
#  'mposing and absolute philosophical edifi',
#  'sing and absolute philosophical edifices',
#  'g and absolute philosophical edifices as',
#  'nd absolute philosophical edifices as th',
#  'absolute philosophical edifices as the d',
#  'olute philosophical edifices as the dogm',
#  'te philosophical edifices as the dogmati',
#  'philosophical edifices as the dogmatists',
#  'losophical edifices as the dogmatists ha',
#  'ophical edifices as the dogmatists have ',
#  'ical edifices as the dogmatists have hit',
#  'l edifices as the dogmatists have hither',
#  'difices as the dogmatists have hitherto ',
#  'ices as the dogmatists have hitherto rea',
#  's as the dogmatists have hitherto reared',
#  's the dogmatists have hitherto reared: p',
#  'he dogmatists have hitherto reared: perh',
#  'dogmatists have hitherto reared: perhaps',
#  'matists have hitherto reared: perhaps so',
#  'ists have hitherto reared: perhaps some ',
#  's have hitherto reared: perhaps some pop',
#  'ave hitherto reared: perhaps some popula',
#  ' hitherto reared: perhaps some popular s',
#  'therto reared: perhaps some popular supe',
#  'rto reared: perhaps some popular superst',
#  ' reared: perhaps some popular superstiti',
#  'ared: perhaps some popular superstition ',
#  'd: perhaps some popular superstition of ',
#  'perhaps some popular superstition of imm',
#  'haps some popular superstition of immemo',
#  's some popular superstition of immemoria',
#  'ome popular superstition of immemorial t',
#  ' popular superstition of immemorial time',
#  'pular superstition of immemorial time (s',
#  'ar superstition of immemorial time (such',
#  'superstition of immemorial time (such as',
#  'erstition of immemorial time (such as th',
#  'tition of immemorial time (such as the s',
#  'ion of immemorial time (such as the soul',
#  ' of immemorial time (such as the soul-su',
#  ' immemorial time (such as the soul-super',
#  'memorial time (such as the soul-supersti',
#  'orial time (such as the soul-superstitio',
#  'al time (such as the soul-superstition, ',
#  'time (such as the soul-superstition, whi',
#  'e (such as the soul-superstition, which,',
#  'such as the soul-superstition, which, in',
#  'h as the soul-superstition, which, in th',
#  's the soul-superstition, which, in the f',
#  'he soul-superstition, which, in the form',
#  'soul-superstition, which, in the form of',
#  'l-superstition, which, in the form of su',
#  'uperstition, which, in the form of subje',
#  'rstition, which, in the form of subject-',
#  'ition, which, in the form of subject- an',
#  'on, which, in the form of subject- and e',
#  ' which, in the form of subject- and ego-',
#  'ich, in the form of subject- and ego-sup',
#  ', in the form of subject- and ego-supers',
#  'n the form of subject- and ego-superstit',
#  'he form of subject- and ego-superstition',
#  'form of subject- and ego-superstition, h',
#  'm of subject- and ego-superstition, has ',
#  'f subject- and ego-superstition, has not',
#  'ubject- and ego-superstition, has not ye',
#  'ect- and ego-superstition, has not yet c',
#  '- and ego-superstition, has not yet ceas',
#  'nd ego-superstition, has not yet ceased ',
#  'ego-superstition, has not yet ceased doi',
#  '-superstition, has not yet ceased doing ',
#  'perstition, has not yet ceased doing mis',
#  'stition, has not yet ceased doing mischi',
#  'tion, has not yet ceased doing mischief)',
#  'n, has not yet ceased doing mischief): p',
#  'has not yet ceased doing mischief): perh',
#  ' not yet ceased doing mischief): perhaps',
#  't yet ceased doing mischief): perhaps so',
#  'et ceased doing mischief): perhaps some ',
#  'ceased doing mischief): perhaps some pla',
#  'sed doing mischief): perhaps some play u',
#  ' doing mischief): perhaps some play upon',
#  'ing mischief): perhaps some play upon wo',
#  ' mischief): perhaps some play upon words',
#  'schief): perhaps some play upon words, a',
#  'ief): perhaps some play upon words, a de',
#  '): perhaps some play upon words, a decep',
#  'perhaps some play upon words, a deceptio',
#  'haps some play upon words, a deception o',
#  's some play upon words, a deception on t',
#  'ome play upon words, a deception on the ',
#  ' play upon words, a deception on the par',
#  'ay upon words, a deception on the part o',
#  'upon words, a deception on the part of g',
#  'n words, a deception on the part of gram',
#  'ords, a deception on the part of grammar',
#  's, a deception on the part of grammar, o',
#  'a deception on the part of grammar, or a',
#  'eception on the part of grammar, or an a',
#  'ption on the part of grammar, or an auda',
#  'on on the part of grammar, or an audacio',
#  'on the part of grammar, or an audacious ',
#  'the part of grammar, or an audacious gen',
#  ' part of grammar, or an audacious genera',
#  'rt of grammar, or an audacious generaliz',
#  'of grammar, or an audacious generalizati',
#  'grammar, or an audacious generalization ',
#  'mmar, or an audacious generalization of ',
#  'r, or an audacious generalization of ver',
#  'or an audacious generalization of very r',
#  'an audacious generalization of very rest',
#  'audacious generalization of very restric',
#  'acious generalization of very restricted',
#  'ous generalization of very restricted, v',
#  ' generalization of very restricted, very',
#  'neralization of very restricted, very pe',
#  'alization of very restricted, very perso',
#  'zation of very restricted, very personal',
#  'ion of very restricted, very personal, v',
#  ' of very restricted, very personal, very',
#  ' very restricted, very personal, very hu',
#  'ry restricted, very personal, very human',
#  'restricted, very personal, very human--a',
#  'tricted, very personal, very human--all-',
#  'cted, very personal, very human--all-too',
#  'd, very personal, very human--all-too-hu',
#  'very personal, very human--all-too-human',
#  'y personal, very human--all-too-human fa',
#  'ersonal, very human--all-too-human facts',
#  'onal, very human--all-too-human facts. t',
#  'l, very human--all-too-human facts. the ',
#  'very human--all-too-human facts. the phi',
#  'y human--all-too-human facts. the philos',
#  'uman--all-too-human facts. the philosoph',
#  'n--all-too-human facts. the philosophy o',
#  'all-too-human facts. the philosophy of t',
#  '-too-human facts. the philosophy of the ',
#  'o-human facts. the philosophy of the dog',
#  'uman facts. the philosophy of the dogmat',
#  'n facts. the philosophy of the dogmatist',
#  'acts. the philosophy of the dogmatists, ',
#  's. the philosophy of the dogmatists, it ',
#  'the philosophy of the dogmatists, it is ',
#  ' philosophy of the dogmatists, it is to ',
#  'ilosophy of the dogmatists, it is to be ',
#  'sophy of the dogmatists, it is to be hop',
#  'hy of the dogmatists, it is to be hoped,',
#  'of the dogmatists, it is to be hoped, wa',
#  'the dogmatists, it is to be hoped, was o',
#  ' dogmatists, it is to be hoped, was only',
#  'gmatists, it is to be hoped, was only a ',
#  'tists, it is to be hoped, was only a pro',
#  'ts, it is to be hoped, was only a promis',
#  ' it is to be hoped, was only a promise f',
#  ' is to be hoped, was only a promise for ',
#  ' to be hoped, was only a promise for tho',
#  ' be hoped, was only a promise for thousa',
#  ' hoped, was only a promise for thousands',
#  'ped, was only a promise for thousands of',
#  ', was only a promise for thousands of ye',
#  'as only a promise for thousands of years',
#  'only a promise for thousands of years af',
#  'y a promise for thousands of years after',
#  ' promise for thousands of years afterwar',
#  'omise for thousands of years afterwards,',
#  'se for thousands of years afterwards, as',
#  'for thousands of years afterwards, as wa',
#  ' thousands of years afterwards, as was a',
#  'ousands of years afterwards, as was astr',
#  'ands of years afterwards, as was astrolo',
#  's of years afterwards, as was astrology ',
#  'f years afterwards, as was astrology in ',
#  'ears afterwards, as was astrology in sti',
#  's afterwards, as was astrology in still ',
#  'fterwards, as was astrology in still ear',
#  'rwards, as was astrology in still earlie',
#  'rds, as was astrology in still earlier t',
#  ', as was astrology in still earlier time',
#  's was astrology in still earlier times, ',
#  'as astrology in still earlier times, in ',
#  'astrology in still earlier times, in the',
#  'rology in still earlier times, in the se',
#  'ogy in still earlier times, in the servi',
#  ' in still earlier times, in the service ',
#  ' still earlier times, in the service of ',
#  'ill earlier times, in the service of whi',
#  ' earlier times, in the service of which ',
#  'rlier times, in the service of which pro',
#  'er times, in the service of which probab',
#  'times, in the service of which probably ',
#  'es, in the service of which probably mor',
#  ' in the service of which probably more l',
#  ' the service of which probably more labo',
#  'e service of which probably more labour,',
#  'ervice of which probably more labour, go',
#  'ice of which probably more labour, gold,',
#  ' of which probably more labour, gold, ac',
#  ' which probably more labour, gold, acute',
#  'ich probably more labour, gold, acutenes',
#  ' probably more labour, gold, acuteness, ',
#  'obably more labour, gold, acuteness, and',
#  'bly more labour, gold, acuteness, and pa',
#  ' more labour, gold, acuteness, and patie',
#  're labour, gold, acuteness, and patience',
#  'labour, gold, acuteness, and patience ha',
#  'our, gold, acuteness, and patience have ',
#  ', gold, acuteness, and patience have bee',
#  'old, acuteness, and patience have been s',
#  ', acuteness, and patience have been spen',
#  'cuteness, and patience have been spent t',
#  'eness, and patience have been spent than',
#  'ss, and patience have been spent than on',
#  ' and patience have been spent than on an',
#  'd patience have been spent than on any a',
#  'atience have been spent than on any actu',
#  'ence have been spent than on any actual ',
#  'e have been spent than on any actual sci',
#  'ave been spent than on any actual scienc',
#  ' been spent than on any actual science h',
#  'en spent than on any actual science hith',
#  'spent than on any actual science hithert',
#  'nt than on any actual science hitherto: ',
#  'than on any actual science hitherto: we ',
#  'n on any actual science hitherto: we owe',
#  'n any actual science hitherto: we owe to',
#  'ny actual science hitherto: we owe to it',
#  'actual science hitherto: we owe to it, a',
#  'ual science hitherto: we owe to it, and ',
#  ' science hitherto: we owe to it, and to ',
#  'ience hitherto: we owe to it, and to its',
#  'ce hitherto: we owe to it, and to its "s',
#  'hitherto: we owe to it, and to its "supe',
#  'herto: we owe to it, and to its "super-t',
#  'to: we owe to it, and to its "super-terr',
#  ' we owe to it, and to its "super-terrest',
#  ' owe to it, and to its "super-terrestria',
#  'e to it, and to its "super-terrestrial" ',
#  'o it, and to its "super-terrestrial" pre',
#  't, and to its "super-terrestrial" preten',
#  'and to its "super-terrestrial" pretensio',
#  ' to its "super-terrestrial" pretensions ',
#  ' its "super-terrestrial" pretensions in ',
#  's "super-terrestrial" pretensions in asi',
#  'super-terrestrial" pretensions in asia a',
#  'er-terrestrial" pretensions in asia and ',
#  'terrestrial" pretensions in asia and egy',
#  'restrial" pretensions in asia and egypt,',
#  'trial" pretensions in asia and egypt, th',
#  'al" pretensions in asia and egypt, the g',
#  ' pretensions in asia and egypt, the gran',
#  'etensions in asia and egypt, the grand s',
#  'nsions in asia and egypt, the grand styl',
#  'ons in asia and egypt, the grand style o',
#  ' in asia and egypt, the grand style of a',
#  ' asia and egypt, the grand style of arch',
#  'ia and egypt, the grand style of archite',
#  'and egypt, the grand style of architectu',
#  ' egypt, the grand style of architecture.',
#  'ypt, the grand style of architecture. it',
#  ', the grand style of architecture. it se',
#  'he grand style of architecture. it seems',
#  'grand style of architecture. it seems th',
#  'nd style of architecture. it seems that ',
#  'style of architecture. it seems that in ',
#  'le of architecture. it seems that in ord',
#  'of architecture. it seems that in order ',
#  'architecture. it seems that in order to ',
#  'hitecture. it seems that in order to ins',
#  'ecture. it seems that in order to inscri',
#  'ure. it seems that in order to inscribe ',
#  '. it seems that in order to inscribe the',
#  't seems that in order to inscribe themse',
#  'eems that in order to inscribe themselve',
#  's that in order to inscribe themselves u',
#  'hat in order to inscribe themselves upon',
#  ' in order to inscribe themselves upon th',
#  ' order to inscribe themselves upon the h',
#  'der to inscribe themselves upon the hear',
#  ' to inscribe themselves upon the heart o',
#  ' inscribe themselves upon the heart of h',
#  'scribe themselves upon the heart of huma',
#  'ibe themselves upon the heart of humanit',
#  ' themselves upon the heart of humanity w',
#  'emselves upon the heart of humanity with',
#  'elves upon the heart of humanity with ev',
#  'es upon the heart of humanity with everl',
#  'upon the heart of humanity with everlast',
#  'n the heart of humanity with everlasting',
#  'he heart of humanity with everlasting cl',
#  'heart of humanity with everlasting claim',
#  'rt of humanity with everlasting claims, ',
#  'of humanity with everlasting claims, all',
#  'humanity with everlasting claims, all gr',
#  'anity with everlasting claims, all great',
#  'ty with everlasting claims, all great th',
#  'with everlasting claims, all great thing',
#  'h everlasting claims, all great things h',
#  'verlasting claims, all great things have',
#  'lasting claims, all great things have fi',
#  'ting claims, all great things have first',
#  'g claims, all great things have first to',
#  'laims, all great things have first to wa',
#  'ms, all great things have first to wande',
#  ' all great things have first to wander a',
#  'l great things have first to wander abou',
#  'reat things have first to wander about t',
#  't things have first to wander about the ',
#  'hings have first to wander about the ear',
#  'gs have first to wander about the earth ',
#  'have first to wander about the earth as ',
#  'e first to wander about the earth as eno',
#  'irst to wander about the earth as enormo',
#  't to wander about the earth as enormous ',
#  'o wander about the earth as enormous and',
#  'ander about the earth as enormous and aw',
#  'er about the earth as enormous and awe-i',
#  'about the earth as enormous and awe-insp',
#  'ut the earth as enormous and awe-inspiri',
#  'the earth as enormous and awe-inspiring ',
#  ' earth as enormous and awe-inspiring car',
#  'rth as enormous and awe-inspiring carica',
#  ' as enormous and awe-inspiring caricatur',
#  ' enormous and awe-inspiring caricatures:',
#  'ormous and awe-inspiring caricatures: do',
#  'ous and awe-inspiring caricatures: dogma',
#  ' and awe-inspiring caricatures: dogmatic',
#  'd awe-inspiring caricatures: dogmatic ph',
#  'we-inspiring caricatures: dogmatic philo',
#  'inspiring caricatures: dogmatic philosop',
#  'piring caricatures: dogmatic philosophy ',
#  'ing caricatures: dogmatic philosophy has',
#  ' caricatures: dogmatic philosophy has be',
#  'ricatures: dogmatic philosophy has been ',
#  'atures: dogmatic philosophy has been a c',
#  'res: dogmatic philosophy has been a cari',
#  ': dogmatic philosophy has been a caricat',
#  'ogmatic philosophy has been a caricature',
#  'atic philosophy has been a caricature of',
#  'c philosophy has been a caricature of th',
#  'hilosophy has been a caricature of this ',
#  'osophy has been a caricature of this kin',
#  'phy has been a caricature of this kind--',
#  ' has been a caricature of this kind--for',
#  's been a caricature of this kind--for in',
#  'een a caricature of this kind--for insta',
#  ' a caricature of this kind--for instance',
#  'caricature of this kind--for instance, t',
#  'icature of this kind--for instance, the ',
#  'ture of this kind--for instance, the ved',
#  'e of this kind--for instance, the vedant',
#  'f this kind--for instance, the vedanta d',
#  'his kind--for instance, the vedanta doct',
#  ' kind--for instance, the vedanta doctrin',
#  'nd--for instance, the vedanta doctrine i',
#  '-for instance, the vedanta doctrine in a',
#  'r instance, the vedanta doctrine in asia',
#  'nstance, the vedanta doctrine in asia, a',
#  'ance, the vedanta doctrine in asia, and ',
#  'e, the vedanta doctrine in asia, and pla',
#  'the vedanta doctrine in asia, and platon',
#  ' vedanta doctrine in asia, and platonism',
#  'danta doctrine in asia, and platonism in',
#  'ta doctrine in asia, and platonism in eu',
#  'doctrine in asia, and platonism in europ',
#  'trine in asia, and platonism in europe. ',
#  'ne in asia, and platonism in europe. let',
#  'in asia, and platonism in europe. let us',
#  'asia, and platonism in europe. let us no',
#  'a, and platonism in europe. let us not b',
#  'and platonism in europe. let us not be u',
#  ' platonism in europe. let us not be ungr',
#  'atonism in europe. let us not be ungrate',
#  'nism in europe. let us not be ungrateful',
#  'm in europe. let us not be ungrateful to',
#  'n europe. let us not be ungrateful to it',
#  'urope. let us not be ungrateful to it, a',
#  'pe. let us not be ungrateful to it, alth',
#  ' let us not be ungrateful to it, althoug',
#  't us not be ungrateful to it, although i',
#  's not be ungrateful to it, although it m',
#  'ot be ungrateful to it, although it must',
#  'be ungrateful to it, although it must ce',
#  'ungrateful to it, although it must certa',
#  'rateful to it, although it must certainl',
#  'eful to it, although it must certainly b',
#  'l to it, although it must certainly be c',
#  'o it, although it must certainly be conf',
#  't, although it must certainly be confess',
#  'although it must certainly be confessed ',
#  'hough it must certainly be confessed tha',
#  'gh it must certainly be confessed that t',
#  'it must certainly be confessed that the ',
#  'must certainly be confessed that the wor',
#  't certainly be confessed that the worst,',
#  'ertainly be confessed that the worst, th',
#  'ainly be confessed that the worst, the m',
#  'ly be confessed that the worst, the most',
#  'be confessed that the worst, the most ti',
#  'confessed that the worst, the most tires',
#  'fessed that the worst, the most tiresome',
#  'sed that the worst, the most tiresome, a',
#  ' that the worst, the most tiresome, and ',
#  'at the worst, the most tiresome, and the',
#  'the worst, the most tiresome, and the mo',
#  ' worst, the most tiresome, and the most ',
#  'rst, the most tiresome, and the most dan',
#  ', the most tiresome, and the most danger',
#  'he most tiresome, and the most dangerous',
#  'most tiresome, and the most dangerous of',
#  't tiresome, and the most dangerous of er',
#  'iresome, and the most dangerous of error',
#  'some, and the most dangerous of errors h',
#  'e, and the most dangerous of errors hith',
#  'and the most dangerous of errors hithert',
#  ' the most dangerous of errors hitherto h',
#  'e most dangerous of errors hitherto has ',
#  'ost dangerous of errors hitherto has bee',
#  ' dangerous of errors hitherto has been a',
#  'ngerous of errors hitherto has been a do',
#  'rous of errors hitherto has been a dogma',
#  's of errors hitherto has been a dogmatis',
#  'f errors hitherto has been a dogmatist e',
#  'rrors hitherto has been a dogmatist erro',
#  'rs hitherto has been a dogmatist error--',
#  'hitherto has been a dogmatist error--nam',
#  'herto has been a dogmatist error--namely',
#  'to has been a dogmatist error--namely, p',
#  'has been a dogmatist error--namely, plat',
#  " been a dogmatist error--namely, plato's",
#  "en a dogmatist error--namely, plato's in",
#  "a dogmatist error--namely, plato's inven",
#  "ogmatist error--namely, plato's inventio",
#  "atist error--namely, plato's invention o",
#  "st error--namely, plato's invention of p",
#  "error--namely, plato's invention of pure",
#  "or--namely, plato's invention of pure sp",
#  "-namely, plato's invention of pure spiri",
#  "mely, plato's invention of pure spirit a",
#  "y, plato's invention of pure spirit and ",
#  "plato's invention of pure spirit and the",
#  "to's invention of pure spirit and the go",
#  's invention of pure spirit and the good ',
#  'nvention of pure spirit and the good in ',
#  'ntion of pure spirit and the good in its',
#  'on of pure spirit and the good in itself',
#  'of pure spirit and the good in itself. b',
#  'pure spirit and the good in itself. but ',
#  'e spirit and the good in itself. but now',
#  'pirit and the good in itself. but now wh',
#  'it and the good in itself. but now when ',
#  'and the good in itself. but now when it ',
#  ' the good in itself. but now when it has',
#  'e good in itself. but now when it has be',
#  'ood in itself. but now when it has been ',
#  ' in itself. but now when it has been sur',
#  ' itself. but now when it has been surmou',
#  'self. but now when it has been surmounte',
#  'f. but now when it has been surmounted, ',
#  'but now when it has been surmounted, whe',
#  ' now when it has been surmounted, when e',
#  'w when it has been surmounted, when euro',
#  'hen it has been surmounted, when europe,',
#  ' it has been surmounted, when europe, ri',
#  ' has been surmounted, when europe, rid o',
#  's been surmounted, when europe, rid of t',
#  'een surmounted, when europe, rid of this',
#  ' surmounted, when europe, rid of this ni',
#  'rmounted, when europe, rid of this night',
#  'unted, when europe, rid of this nightmar',
#  'ed, when europe, rid of this nightmare, ',
#  ' when europe, rid of this nightmare, can',
#  'en europe, rid of this nightmare, can ag',
#  'europe, rid of this nightmare, can again',
#  'ope, rid of this nightmare, can again dr',
#  ', rid of this nightmare, can again draw ',
#  'id of this nightmare, can again draw bre',
#  'of this nightmare, can again draw breath',
#  'this nightmare, can again draw breath fr',
#  's nightmare, can again draw breath freel',
#  'ightmare, can again draw breath freely a',
#  'tmare, can again draw breath freely and ',
#  're, can again draw breath freely and at ',
#  ' can again draw breath freely and at lea',
#  'n again draw breath freely and at least ',
#  'gain draw breath freely and at least enj',
#  'n draw breath freely and at least enjoy ',
#  'raw breath freely and at least enjoy a h',
#  ' breath freely and at least enjoy a heal',
#  'eath freely and at least enjoy a healthi',
#  'h freely and at least enjoy a healthier-',
#  'reely and at least enjoy a healthier--sl',
#  'ly and at least enjoy a healthier--sleep',
#  'and at least enjoy a healthier--sleep, w',
#  ' at least enjoy a healthier--sleep, we, ',
#  ' least enjoy a healthier--sleep, we, who',
#  'ast enjoy a healthier--sleep, we, whose ',
#  ' enjoy a healthier--sleep, we, whose dut',
#  'joy a healthier--sleep, we, whose duty i',
#  ' a healthier--sleep, we, whose duty is w',
#  'healthier--sleep, we, whose duty is wake',
#  'lthier--sleep, we, whose duty is wakeful',
#  'ier--sleep, we, whose duty is wakefulnes',
#  '--sleep, we, whose duty is wakefulness i',
#  'leep, we, whose duty is wakefulness itse',
#  'p, we, whose duty is wakefulness itself,',
#  'we, whose duty is wakefulness itself, ar',
#  ' whose duty is wakefulness itself, are t',
#  'ose duty is wakefulness itself, are the ',
#  ' duty is wakefulness itself, are the hei',
#  'ty is wakefulness itself, are the heirs ',
#  'is wakefulness itself, are the heirs of ',
#  'wakefulness itself, are the heirs of all',
#  'efulness itself, are the heirs of all th',
#  'lness itself, are the heirs of all the s',
#  'ss itself, are the heirs of all the stre',
#  'itself, are the heirs of all the strengt',
#  'elf, are the heirs of all the strength w',
#  ', are the heirs of all the strength whic',
#  're the heirs of all the strength which t',
#  'the heirs of all the strength which the ',
#  ' heirs of all the strength which the str',
#  'irs of all the strength which the strugg',
#  ' of all the strength which the struggle ',
#  ' all the strength which the struggle aga',
#  'l the strength which the struggle agains',
#  'he strength which the struggle against t',
#  'strength which the struggle against this',
#  'ength which the struggle against this er',
#  'th which the struggle against this error',
#  'which the struggle against this error ha',
#  'ch the struggle against this error has f',
#  'the struggle against this error has fost',
#  ' struggle against this error has fostere',
#  'ruggle against this error has fostered. ',
#  'gle against this error has fostered. it ',
#  ' against this error has fostered. it amo',
#  'ainst this error has fostered. it amount',
#  'st this error has fostered. it amounted ',
#  'this error has fostered. it amounted to ',
#  's error has fostered. it amounted to the',
#  'rror has fostered. it amounted to the ve',
#  'r has fostered. it amounted to the very ',
#  'as fostered. it amounted to the very inv',
#  'fostered. it amounted to the very invers',
#  'tered. it amounted to the very inversion',
#  'ed. it amounted to the very inversion of',
#  ' it amounted to the very inversion of tr',
#  ' amounted to the very inversion of truth',
#  'ounted to the very inversion of truth, a',
#  'ted to the very inversion of truth, and ',
#  ' to the very inversion of truth, and the',
#  ' the very inversion of truth, and the de',
#  'e very inversion of truth, and the denia',
#  'ery inversion of truth, and the denial o',
#  ' inversion of truth, and the denial of t',
#  'version of truth, and the denial of the ',
#  'sion of truth, and the denial of the per',
#  'n of truth, and the denial of the perspe',
#  'f truth, and the denial of the perspecti',
#  'ruth, and the denial of the perspective-',
#  'h, and the denial of the perspective--th',
#  'and the denial of the perspective--the f',
#  ' the denial of the perspective--the fund',
#  'e denial of the perspective--the fundame',
#  'enial of the perspective--the fundamenta',
#  'al of the perspective--the fundamental c',
#  'of the perspective--the fundamental cond',
#  'the perspective--the fundamental conditi',
#  ' perspective--the fundamental condition-',
#  'rspective--the fundamental condition--of',
#  'ective--the fundamental condition--of li',
#  'ive--the fundamental condition--of life,',
#  '--the fundamental condition--of life, to',
#  'he fundamental condition--of life, to sp',
#  'fundamental condition--of life, to speak',
#  'damental condition--of life, to speak of',
#  'ental condition--of life, to speak of sp',
#  'al condition--of life, to speak of spiri',
#  'condition--of life, to speak of spirit a',
#  'dition--of life, to speak of spirit and ',
#  'ion--of life, to speak of spirit and the',
#  '--of life, to speak of spirit and the go',
#  'f life, to speak of spirit and the good ',
#  'ife, to speak of spirit and the good as ',
#  ', to speak of spirit and the good as pla',
#  'o speak of spirit and the good as plato ',
#  'peak of spirit and the good as plato spo',
#  'k of spirit and the good as plato spoke ',
#  'f spirit and the good as plato spoke of ',
#  'pirit and the good as plato spoke of the',
#  'it and the good as plato spoke of them; ',
#  'and the good as plato spoke of them; ind',
#  ' the good as plato spoke of them; indeed',
#  'e good as plato spoke of them; indeed on',
#  'ood as plato spoke of them; indeed one m',
#  ' as plato spoke of them; indeed one migh',
#  ' plato spoke of them; indeed one might a',
#  'ato spoke of them; indeed one might ask,',
#  ' spoke of them; indeed one might ask, as',
#  'oke of them; indeed one might ask, as a ',
#  ' of them; indeed one might ask, as a phy',
#  ' them; indeed one might ask, as a physic',
#  'em; indeed one might ask, as a physician',
#  ' indeed one might ask, as a physician: "',
#  'deed one might ask, as a physician: "how',
#  'd one might ask, as a physician: "how di',
#  'ne might ask, as a physician: "how did s',
#  'might ask, as a physician: "how did such',
#  'ht ask, as a physician: "how did such a ',
#  'ask, as a physician: "how did such a mal',
#  ', as a physician: "how did such a malady',
#  's a physician: "how did such a malady at',
#  ' physician: "how did such a malady attac',
#  'ysician: "how did such a malady attack t',
#  'cian: "how did such a malady attack that',
#  'n: "how did such a malady attack that fi',
#  '"how did such a malady attack that fines',
#  'w did such a malady attack that finest p',
#  'id such a malady attack that finest prod',
#  'such a malady attack that finest product',
#  'h a malady attack that finest product of',
#  ' malady attack that finest product of an',
#  'lady attack that finest product of antiq',
#  'y attack that finest product of antiquit',
#  'ttack that finest product of antiquity, ',
#  'ck that finest product of antiquity, pla',
#  'that finest product of antiquity, plato?',
#  't finest product of antiquity, plato? ha',
#  'inest product of antiquity, plato? had t',
#  'st product of antiquity, plato? had the ',
#  'product of antiquity, plato? had the wic',
#  'duct of antiquity, plato? had the wicked',
#  't of antiquity, plato? had the wicked so',
#  'f antiquity, plato? had the wicked socra',
#  'ntiquity, plato? had the wicked socrates',
#  'quity, plato? had the wicked socrates re',
#  'ty, plato? had the wicked socrates reall',
#  ' plato? had the wicked socrates really c',
#  'ato? had the wicked socrates really corr',
#  '? had the wicked socrates really corrupt',
#  'ad the wicked socrates really corrupted ',
#  'the wicked socrates really corrupted him',
#  ' wicked socrates really corrupted him? w',
#  'cked socrates really corrupted him? was ',
#  'd socrates really corrupted him? was soc',
#  'ocrates really corrupted him? was socrat',
#  'ates really corrupted him? was socrates ',
#  's really corrupted him? was socrates aft',
#  'eally corrupted him? was socrates after ',
#  'ly corrupted him? was socrates after all',
#  'corrupted him? was socrates after all a ',
#  'rupted him? was socrates after all a cor',
#  'ted him? was socrates after all a corrup',
#  ' him? was socrates after all a corrupter',
#  'm? was socrates after all a corrupter of',
#  'was socrates after all a corrupter of yo',
#  ' socrates after all a corrupter of youth',
#  'crates after all a corrupter of youths, ',
#  'tes after all a corrupter of youths, and',
#  ' after all a corrupter of youths, and de',
#  'ter all a corrupter of youths, and deser',
#  ' all a corrupter of youths, and deserved',
#  'l a corrupter of youths, and deserved hi',
#  ' corrupter of youths, and deserved his h',
#  'rrupter of youths, and deserved his heml',
#  'pter of youths, and deserved his hemlock',
#  'r of youths, and deserved his hemlock?" ',
#  'f youths, and deserved his hemlock?" but',
#  'ouths, and deserved his hemlock?" but th',
#  'hs, and deserved his hemlock?" but the s',
#  ' and deserved his hemlock?" but the stru',
#  'd deserved his hemlock?" but the struggl',
#  'eserved his hemlock?" but the struggle a',
#  ...]

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print("-")
# Out:
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 198s 125ms/step - loss: 2.2763
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: "roken strength of will and desire for po"
# ...Generated:  ssible the man and such a the can the despreations and such a struct of the the will the canster of the man and agrays of man and among the presente of the the can the presente and action in the presente of the explession the such a presentions of such a canstically the concertion the deart of such a stands the such a presente of the presence and among the one the presence and such a strenger of t
# -
# ...Diversity: 0.5
# ...Generating with seed: "roken strength of will and desire for po"
# ...Generated:  ssing the man for the sense that it is and charce of all the plawe him of the and are and such a stand davery and agcient mane and more of a cance of the such of all still as a minder intellection tho the oncernis no such be disence of understance in a man it a the preason, sund of a all that the as the must acthance of some of such be despruative of the such atter of made it againd, and such who
# -
# ...Diversity: 1.0
# ...Generating with seed: "roken strength of will and desire for po"
# ...Generated:  rtary thtillek under.--theme oke imperforing it is ho the loge be thousn an oth to mua sule hastersacheverdy from morto callomitikived doow no only presentment of his mode amay wo agad, eventelf parth sungroridg my a thote, a so the pheass the hid."--too-authess, nativelyy an, mott" matshersk add contcivions the ducar, reimany atouss--we whate reanthour of onm that enigidedgeally assurdle sbylecks
# -
# ...Diversity: 1.2
# ...Generating with seed: "roken strength of will and desire for po"
# ...Generated:  wers asmialmly-try. not ither atetlixefuling extindswatiky a s _tartf lifudengeds,  a! in the exerm nowaild. i purateralrausddrich ompracionsies.--the subcecred and adknovigle--bbok." "s9olety of masadials tyr co folly maken 5ake forth co mades who jagte, pelistatt_, (; eld: a do--and shild esuration "poanuse" not the out of antimelt , it eurselves,  5pe peavenal the ockite al will ciln! itnesse o
# -
#  193/1565 ━━━━━━━━━━━━━━━━━━━━ 2:44 120ms/step - loss: 1.6308
